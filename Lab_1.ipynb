# %% [markdown]
# # Variable and Data Types

# %%
# question 1
age = 25
print(type(25))
# Out:
# <class 'int'>

# %%
# Question 2
name = "Shishir"
print(name[0])
# Out:
# S

# %%
# Question 3
fruits = ["Apple", "Banana", "Mango"]
print(fruits[1])
# Out:
# Banana

# %% [markdown]
# # Basic Operators and String Operators

# %%
# Question 4
x = 10
y = 3
result = (x+y)*5
print(result)
# Out:
# 65

# %%
# string concatenation
first = "hello"
second = "world"
result = first + " " + second
print(result)
# Out:
# hello world

# %%
# repeating strings
say = "Hi"
print(say*4)
# Out:
# HiHiHiHi

# %%
n = 1
if n >0:
    print("positive")
elif n<0:
    print("negative")
else:
    print("zero")
# Out:
# positive

# %%
for i in range(1,6):
    print(i, end=" ")
# Out:
# 1 2 3 4 5

# %%
count = 1
while count<=3:
  print(count)
  count+=1
# Out:
# 1
# 2
# 3

# %%
def add_two(a, b):
  return a+b

print(add_two(2,3))
# Out:
# 5

# %%
import math
print(math.sqrt(16))
print(int(math.sqrt(16)))
# Out:
# 4.0
# 4

# %%
def fun():
  print("Hello, Python")

fun()
# Out:
# Hello, Python

# %%
name = "Shishir"
age = 22
gpa = 4.00
print(f"My name is {name}. I'm {age} years old. I got {gpa} GPA in examination")
# Out:
# My name is Shishir. I'm 22 years old. I got 4.0 GPA in examination

# %%
cities = ["Kathmandu", "Pokhara", "Jhapa", "Chitwan", "Kawasoti"]
print(cities[0], cities[-1])
# Out:
# Kathmandu Kawasoti

# %%
length = 5
breadth = 4
print(length*breadth)
# Out:
# 20

# %%
string = "programming"
print(string[:6])
# Out:
# progra

# %%
num = 5
if num%2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Odd

# %%
percentage = float(input())
if percentage >= 90:
  print("Grade A")
elif 75<=percentage<90:
  print("Grade B")
elif 50>percentage<=75:
  print("Grade C")
elif percentage<50:
  print("You have failed the exam")
# Out:
# 45
# Grade C

# %%
for i in range (1, 11):
  print(i*5, end=" ")
# Out:
# 5 10 15 20 25 30 35 40 45 50

# %%
sum = 0
for i in range(1, 11, 1):
  sum+=i
print(sum)
# Out:
# 55

# %%
def factorial(n):
  result = 1
  for i in range(1, n+1):
    result*=i
  return result
print(factorial(4))
# Out:
# 24

# %%
import math
print(round(math.pi, 3))
# Out:
# 3.142
